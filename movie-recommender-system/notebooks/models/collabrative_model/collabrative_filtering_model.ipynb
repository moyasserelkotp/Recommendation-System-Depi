# %% [markdown]
# ## 🎯 Problem Statement (MovieLens Dataset)
#
# #####  In the modern digital entertainment landscape, users face a constant challenge: what to watch next? With 'thousands of movie options available on various streaming platforms, making a decision becomes difficult without personalized guidance. Generic `Top 10` lists or trending movies often fail to reflect the unique tastes of individual users.
#
# ##### To solve this, we aim to build an **intelligent movie recommendation system** that uses the MovieLens dataset—a widely-used benchmark dataset containing millions of movie ratings provided by real users. The MovieLens dataset offers a rich foundation to analyze user preferences, movie metadata (titles, genres, release dates), and rating behaviors.
#
# ##### The key challenge lies in extracting valuable insights from this large and sparse user-item interaction matrix, and then transforming those insights into meaningful, personalized suggestions. A system that can learn from both user behavior patterns and movie features is critical to improving user satisfaction and engagement.
#
# ##### The goal is to build a solution that:
#   - Understands user preferences through historical ratings.
#   - Explores the content side (genre, title, etc.) to recommend similar movies.
#   - Uses hybrid recommendation models to combine collaborative filtering and content-based filtering.
#   - Can be deployed as an interactive application with real-time suggestions and updates.

# %% [markdown]
# <div style="display: flex; justify-content: center;">
#   <img src="https://user-images.githubusercontent.com/86877457/132905471-3ef27af4-ecc6-44bf-a47c-5ccf2250410c.jpg" style="width:100%; max-width:1000px;">
# </div>

# %% [markdown]
# ## ✅ Project Objectives (Tailored for MovieLens Dataset)
#
# #### This project aims to develop a feature-rich movie recommendation engine using the MovieLens dataset, leveraging its rich user-movie rating data and metadata to drive powerful, personalized suggestions. Our objectives include:
#
# - Data Acquisition & Understanding:
#     -  Load and explore the MovieLens dataset (e.g., 100k, 1M, or 20M versions).
#     - Analyze user behavior (e.g., rating frequency, genre preference).
#     - Understand data sparsity and user-item interaction distribution.
#
# - Data Preprocessing & Feature Engineering:
#     - Clean and preprocess data: handle missing values, duplicates, and anomalies.
#     - Engineer content features: one-hot encoding of genres, TF-IDF for movie titles/descriptions.
#     - Create user profiles and similarity matrices for collaborative filtering.
#
#
# - Modeling Techniques:
#     -  Collaborative Filtering:
#         Use algorithms like Singular Value Decomposition (SVD) and Alternating Least Squares (ALS) to identify latent patterns.
#     -  Content-Based Filtering:
#         Recommend based on genre similarity and textual similarity (e.g., cosine similarity on TF-IDF vectors).
#     - Hybrid Approaches:
#         Combine collaborative and content-based strategies to enhance prediction accuracy.
#
#
# - Evaluation and Optimization:
#     - Split the dataset using techniques like time-aware splitting or leave-one-out.
#     - Evaluate models with metrics like RMSE, MAE, Precision@K, Recall@K, NDCG@K.
#     - Perform hyperparameter tuning to optimize model performance.
#
# - Deployment and Integration:
#     - Develop a backend API using Flask or FastAPI that exposes /recommend endpoints.
#     - Create an interactive frontend using Streamlit that allows users to:
#         - Select user IDs or favorite movies.
#         - View real-time movie recommendations.
#     -  Track and version experiments with MLflow and manage data pipelines with DVC.
#
#
# - Monitoring, Feedback, and Improvement:
#     - Design a retraining loop for incorporating new ratings and user feedback.
#     - Allow real-time rating input and dynamically adjust recommendations.
#
#
# - Final Output and Presentation:
#     - Document the methodology, model performance, and design decisions.
#     - Prepare a demo with a functional user interface and recommendation flow.
#     - Publish the codebase with a clear README and deployment instructions.

# %% [markdown]
# ![photo_2025-04-08_17-56-31.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # 🎬 MOVIE RECOMMENDATION SYSTEM (MOVIELENS)
# ### 📄 Project Documentation – Table of Contents
#
# ---
#
# ## 📌 1. PROJECT FOUNDATION
# ### 🔧 1.1 System Initialization
# - ✅ Library Imports (`pandas`, `numpy`, `tensorflow`)
# - ⚙️ Environment Configuration
# - 🔁 Version Control Setup
#
# ### 📥 1.2 Data Acquisition
# - 🎞️ MovieLens Dataset Selection (20M)
# - 🔽 Data Download Protocol
# - 🗂️ Storage Architecture
#
# ---
#
# ## 🏗️ 2. DATA ENGINEERING
# ### 📂 2.1 Data Loading Framework
# - 📊 Ratings Dataset Schema
# - 🎬 Movies Metadata Structure
# - ➕ Auxiliary Data (Tags / Links) Integration
#
# ### 🔍 2.2 Data Quality Assessment
# - 🚫 Missing Value Analysis
# - 🧬 Duplicate Detection System
# - ⏳ Temporal Data Conversion
#
# ### 🔄 2.3 Feature Transformation
# - 🎭 Genre Decomposition Matrix
# - 👥 User-Movie Interaction Grid
# - 📉 Rating Normalization Pipeline
#
# ---
#
# ## 📊 3. EXPLORATORY ANALYSIS
# ### 📈 3.1 Statistical Profiling
# - 📚 Rating Distribution Analysis
# - 👤 User Engagement Metrics
# - 🌟 Movie Popularity Index
#
# ### 🖼️ 3.2 Visual Analytics
# - 🕒 Temporal Activity Heatmaps
# - 🎼 Genre Popularity Trends
# - ☁️ Content Tag Cloud Visualizations
#
# ---
#
# ## 🤖 4. MACHINE LEARNING FRAMEWORK
# ### 🧠 4.1 Feature Engineering
# - 🧍 User Preference Vectors
# - 🎥 Movie Attribute Embeddings
# - 🔤 Semantic Title Features (TF-IDF)
#
# ### 🧮 4.2 Recommendation Algorithms
# #### 🔄 Collaborative Filtering
# - 📐 SVD Matrix Factorization
# - 🔁 Alternating Least Squares (ALS)
#
# #### 🧾 Content-Based Filtering
# - 🎭 Genre Similarity Scoring
# - 🧬 Semantic Content Matching
#
# #### 🔗 Hybrid Approach
# - ⚖️ Weighted Ensemble Method
# - 🧱 Stacked Recommendation Architecture
#
# ---
#
# ## 🛠️ 5. MODEL OPTIMIZATION
# ### 📊 5.1 Evaluation Protocol
# - ⏰ Temporal Validation Strategy
# - 📏 Metrics Suite:
#   - 🎯 RMSE / MAE (Prediction Accuracy)
#   - 🧭 NDCG@K (Ranking Quality)
#   - 🔍 Precision@K / Recall@K (Relevance Metrics)
#
# ### 🎯 5.2 Hyperparameter Tuning
# - 📊 Grid Search Configuration
# - 🎲 Randomized Parameter Optimization
#
# ---
#
# ## 🚀 6. DEPLOYMENT ARCHITECTURE
# ### 🧪 6.1 MLOps Infrastructure
# - 🔍 Experiment Tracking (MLflow)
# - 🧾 Data Versioning (DVC)
#
# ### 🔌 6.2 API Services
# - 🌐 RESTful Recommendation Endpoints
# - 🧰 FastAPI / Flask Backend
#
# ### 💻 6.3 User Interface
# - 📊 Streamlit Dashboard
#
# ---
#
# ## 🔍 7. SYSTEM MONITORING
# ### 🗂️ 7.1 Feedback Mechanisms
# - 📈 User Interaction Logging
# - 👀 Implicit Feedback Collection
#
# ### ♻️ 7.2 Continuous Improvement
# - 🔁 Model Retraining Schedule
# - ⚠️ Concept Drift Detection
#
# ---
#
# ## 📦 8. PROJECT DELIVERABLES
# ### 📑 8.1 Technical Documentation
# - 🏗️ System Architecture Diagrams
# - 🧾 API Specifications
#
# ### 🖥️ 8.2 Presentation Materials
# - 📝 Executive Summary
# - 📈 Model Performance Benchmarking
# - 🎥 Demonstration Scenarios
#
# ### 🗃️ 8.3 Repository Structure
# - 🧱 Code Organization
# - 🚀 Deployment Artifacts
#
# ---
#
# ## 🌱 9. ENHANCEMENT ROADMAP
# ### 🌟 9.1 Advanced Features
# - 🌐 TMDB API Integration
#   - 🎞️ High-Resolution Movie Posters
#   - 🎬 Trailer Embedding System
#   - 🎭 Celebrity Cast Information
#
# - ❄️ Cold Start Solutions
#   - 🧑‍🤝‍🧑 Demographic Filtering
#   - 📚 Knowledge-Based Recommendations
#
# ### ⚙️ 9.2 Scalability Upgrades
# - ⏱️ Real-Time Recommendation Engine
# - 🧮 Distributed Computing Implementation
#
# ---
#
# **📌 Project Version**: `1.0`
# **🕒 Last Updated**: `8/4/2025`

# %% [markdown]
# ## 4. Machine Learning Framweork

# %%
# Data manipulation and analysis
import pandas as pd 
import numpy as np    

# Data visualization
import matplotlib.pyplot as plt  
import seaborn as sns            
import plotly.exceptions as px  

# Ignore warnings (useful during development to reduce console noise)
import warnings
warnings.filterwarnings("ignore")

# TensorFlow and Keras for deep learning and recommendation systems
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, optimizers, losses, metrics  
from tensorflow.keras.callbacks import EarlyStopping, TensorBoard, ReduceLROnPlateau, ModelCheckpoint  
from tensorflow.keras import regularizers 
import tensorflow_recommenders as tfrs  
from tensorflow.keras import metrics as keras_metrics  # To avoid conflicts with sklearn.metrics
from tensorflow_recommenders import metrics as tfrs_metrics


# Scikit-learn for preprocessing, model evaluation, and splitting
from sklearn.model_selection import train_test_split 
from sklearn.preprocessing import StandardScaler, MinMaxScaler  
from sklearn.feature_extraction.text import TfidfVectorizer 
from sklearn.metrics.pairwise import cosine_similarity 
from sklearn.impute import SimpleImputer  
from sklearn.metrics import mean_squared_error, mean_absolute_error  
from sklearn.metrics import r2_score, precision_score, recall_score, f1_score, ndcg_score  

# Other utility libraries
import tempfile  # For creating temporary directories/files
import os       
import math     
from collections import defaultdict  # For handling dictionary-like structures with default values

# Deployment the model
from tensorflow.keras.models import load_model  # To load a saved Keras model
from keras.saving import register_keras_serializable  # To register custom Keras components for saving/loading
import pickle  # For serializing Python objects (like models or encoders)
# Out:
# c:\Program Files\Python312\Lib\site-packages\matplotlib\projections\__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "

# %% [markdown]
# ### 4.1 Feature Engineering

# %%
class NeuralCollaborativeFilteringDataProcessor:
    def __init__(self, df):
        self.df = df.copy()
        self._preprocess_data()
        
    def _preprocess_data(self):
        """Enhanced data cleaning and preparation"""
        # Robust missing value handling
        self.df["movies_avg_rating"] = (
            self.df["movies_avg_rating"]
            .fillna(self.df.groupby("movieId")["movies_avg_rating"].transform("mean"))
            .fillna(self.df["movies_avg_rating"].mean())
        )

        # Enhanced user statistics
        self.df["user_rating_count"] = self.df.groupby("userId")["user_rating"].transform("count")
        self.df["user_rating_avg"] = self.df.groupby("userId")["user_rating"].transform("mean")
        self.df["user_rating_std"] = (
            self.df.groupby("userId")["user_rating"].transform("std").fillna(0)
        )

        # Create mappings for user and movie IDs
        self.user_ids = self.df['userId'].unique().tolist()
        self.movie_ids = self.df['movieId'].unique().tolist()
        
        self.user_id_lookup = {id: idx for idx, id in enumerate(self.user_ids)}
        self.movie_id_lookup = {id: idx for idx, id in enumerate(self.movie_ids)}
        self.reverse_movie_id_lookup = {idx: id for id, idx in self.movie_id_lookup.items()}
        
        # Encode IDs
        self.df['user_id_encoded'] = self.df['userId'].map(self.user_id_lookup)
        self.df['movie_id_encoded'] = self.df['movieId'].map(self.movie_id_lookup)
        
        # Create movie title mapping
        self.movie_titles = dict(zip(self.df['movieId'], self.df['movie_title']))
        
    def get_train_test_split(self, test_size=0.2, random_state=42):
        """Split data into train and test sets"""
        X = self.df[['user_id_encoded', 'movie_id_encoded']]
        y = self.df['user_rating']
        return train_test_split(X, y, test_size=test_size, random_state=random_state)

# %% [markdown]
# ### 4.2 Recommendation Algorithm

# %%
    class NeuralCollaborativeFilteringModel(tfrs.Model):
        def __init__(self, user_count, movie_count, embedding_dim=64):
            super().__init__()
            
            # User and movie embedding layers
            self.user_embedding = layers.Embedding(
                input_dim=user_count,
                output_dim=embedding_dim,
                embeddings_regularizer=regularizers.l2(1e-6)
            )
            self.movie_embedding = layers.Embedding(
                input_dim=movie_count,
                output_dim=embedding_dim,
                embeddings_regularizer=regularizers.l2(1e-6)
            )
            
            # Neural network layers
            self.mlp_layers = tf.keras.Sequential([
                layers.Dense(256, activation='relu'),
                layers.BatchNormalization(),
                layers.Dropout(0.3),
                layers.Dense(128, activation='relu'),
                layers.Dense(1)
            ])
            
            # Rating prediction task
            self.task = tfrs.tasks.Ranking(
                loss=losses.MeanSquaredError(),
                metrics=[
                    tf.keras.metrics.RootMeanSquaredError(),
                    tf.keras.metrics.MeanAbsoluteError()
                ]
            )
            
        def call(self, features):
            user_embeddings = self.user_embedding(features["user_id_encoded"])
            movie_embeddings = self.movie_embedding(features["movie_id_encoded"])
            concatenated = tf.concat([user_embeddings, movie_embeddings], axis=1)
            return self.mlp_layers(concatenated)
            
        def compute_loss(self, inputs, training=False):
            # Create a copy of the features instead of modifying inputs
            features = {
                "user_id_encoded": inputs["user_id_encoded"],
                "movie_id_encoded": inputs["movie_id_encoded"]
            }
            labels = inputs["user_rating"]  # Don't pop, just access
            
            predictions = self(features)
            loss = self.task(labels=labels, predictions=predictions)
            regularization_loss = tf.reduce_sum(self.losses)
            return loss + 1e-6 * regularization_loss

# %% [markdown]
# #### Neural Collaborative Filtering System

# %%
class NeuralCollaborativeFilteringSystem:  
    def __init__(self, data_processor):
        self.data_processor = data_processor
        self.model = None
        self.scaler = MinMaxScaler(feature_range=(0, 1))
        self.train_ds = None
        self.test_ds = None
        self.original_test_df = None

    def _create_dataset(self, X, y, batch_size=1024, shuffle=False):
        """Create properly formatted datasets that match model expectations"""
        # Create features dictionary including the target
        features = {
            "user_id_encoded": X["user_id_encoded"].values,
            "movie_id_encoded": X["movie_id_encoded"].values,
            "user_rating": y.flatten()  # Include target in features dict
        }
        
        ds = tf.data.Dataset.from_tensor_slices(features)
        
        if shuffle:
            ds = ds.shuffle(buffer_size=len(X)*2)
            
        return ds.batch(batch_size).cache().prefetch(tf.data.AUTOTUNE)

    def prepare_datasets(self, batch_size=1024):
        """Prepare datasets ensuring proper format"""
        X_train, X_test, y_train, y_test = self.data_processor.get_train_test_split()
        
        # Scale ratings
        y_train = self.scaler.fit_transform(y_train.values.reshape(-1, 1))
        y_test = self.scaler.transform(y_test.values.reshape(-1, 1))
        
        # Store original test data
        self.original_test_df = self.data_processor.df.loc[X_test.index][['userId', 'movieId', 'user_rating']]
        
        # Create datasets
        self.train_ds = self._create_dataset(X_train, y_train, batch_size, shuffle=True)
        self.test_ds = self._create_dataset(X_test, y_test, batch_size)
        
        return self.train_ds, self.test_ds

    def train_model(self, embedding_dim=64, epochs=30, learning_rate=0.001):
        """Train model with proper data handling"""
        if self.train_ds is None or self.test_ds is None:
            raise RuntimeError("Datasets not prepared. Call prepare_datasets() first.")
            
        user_count = len(self.data_processor.user_ids)
        movie_count = len(self.data_processor.movie_ids)
        
        # Initialize model
        self.model = NeuralCollaborativeFilteringModel(user_count, movie_count, embedding_dim)
        
        # Compile model
        self.model.compile(optimizer=optimizers.Adam(learning_rate=learning_rate))
        
        # Callbacks
        callbacks = [
            EarlyStopping(patience=5, monitor='val_root_mean_squared_error', mode='min'),
            ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=2)
        ]
        
        # Train model
        print(f"Starting training with {len(list(self.train_ds.unbatch()))} samples")
        history = self.model.fit(
            self.train_ds,
            validation_data=self.test_ds,
            epochs=epochs,
            callbacks=callbacks,
            verbose=1
        )
        
        return history
        
    def evaluate_model(self):
        """Evaluate model performance"""
        if self.test_ds is None:
            raise ValueError("Test dataset not prepared. Call prepare_datasets() first.")
            
        results = self.model.evaluate(self.test_ds, return_dict=True)
        results = {k: float(v) for k, v in results.items()}  # Convert numpy types to native Python
        
        # Add additional evaluation metrics
        predictions = self.model.predict(self.test_ds)
        y_true = np.concatenate([batch["user_rating"].numpy() for batch in self.test_ds])
        y_pred = np.concatenate(predictions)
        
        # Inverse transform scaled ratings
        y_true = self.scaler.inverse_transform(y_true.reshape(-1, 1)).flatten()
        y_pred = self.scaler.inverse_transform(y_pred.reshape(-1, 1)).flatten()
        
        results['mae'] = float(mean_absolute_error(y_true, y_pred))
        results['rmse'] = float(np.sqrt(mean_squared_error(y_true, y_pred)))
        
        return results
        
    def recommend_for_user(self, user_id, top_n=10, diversity=0.2):
        """Generate recommendations for a user with diversity"""
        try:
            if user_id not in self.data_processor.user_id_lookup:
                return self.get_popular_recommendations(top_n)
                
            user_encoded = self.data_processor.user_id_lookup[user_id]
            seen_movies = set(self.data_processor.df[self.data_processor.df['userId'] == user_id]['movieId'])
            
            # Get all unseen movies
            candidate_movies = [mid for mid in self.data_processor.movie_ids if mid not in seen_movies]
            movie_encoded = [self.data_processor.movie_id_lookup[mid] for mid in candidate_movies]
            
            # Batch predictions to avoid memory issues
            batch_size = 1000
            predictions = []
            for i in range(0, len(movie_encoded), batch_size):
                batch = movie_encoded[i:i+batch_size]
                user_batch = [user_encoded] * len(batch)
                
                preds = self.model({
                    "user_id_encoded": tf.convert_to_tensor(user_batch),
                    "movie_id_encoded": tf.convert_to_tensor(batch)
                }).numpy().flatten()
                
                predictions.extend(preds)
            
            predictions = np.array(predictions)
            
            # Add diversity
            if diversity > 0:
                noise = np.random.normal(0, diversity * np.std(predictions), len(predictions))
                predictions = predictions + noise
                
            # Get top recommendations
            top_indices = np.argsort(-predictions)[:top_n*3]
            candidates = pd.DataFrame({
                'movieId': np.array(candidate_movies)[top_indices],
                'predicted_rating': predictions[top_indices]
            })
            
            # Merge with movie info
            candidates = candidates.merge(
                self.data_processor.df[['movieId', 'movie_title', 'genres', 'movies_avg_rating']].drop_duplicates(),
                on='movieId'
            )
            
            # Deduplicate and diversify by genres
            final_recs = []
            seen_genres = set()
            for _, row in candidates.iterrows():
                movie_genres = set(row['genres'].split('|')) if pd.notna(row['genres']) else set()
                
                if len(seen_genres & movie_genres) / len(movie_genres) > 0.7:
                    continue
                    
                final_recs.append({
                    "movieId": row['movieId'],
                    "title": row['movie_title'],
                    "genres": row['genres'],
                    "predicted_rating": float(row['predicted_rating']),
                    "average_rating": row['movies_avg_rating']
                })
                seen_genres.update(movie_genres)
                
                if len(final_recs) >= top_n:
                    break
                    
            return pd.DataFrame(final_recs)
            
        except Exception as e:
            print(f"Error in recommendations for user {user_id}: {str(e)}")
            return self.get_popular_recommendations(top_n)
            
    def get_popular_recommendations(self, top_n=10):
        """Fallback to popular items when personalized recs fail"""
        try:
            popular = self.data_processor.df.groupby('movieId').agg({
                'movie_title': 'first',
                'genres': 'first',
                'movies_avg_rating': 'mean',
                'user_rating': 'count'
            }).sort_values(['user_rating', 'movies_avg_rating'], ascending=False).head(top_n)
            
            return pd.DataFrame([{
                "movieId": idx,
                "title": row['movie_title'],
                "genres": row['genres'],
                "predicted_rating": row['movies_avg_rating'],
                "average_rating": row['movies_avg_rating'],
                "popularity": row['user_rating']
            } for idx, row in popular.iterrows()])
            
        except Exception as e:
            print(f"Error in popular recommendations: {str(e)}")
            return pd.DataFrame([{
                "movieId": -1,
                "title": "No recommendations available",
                "genres": "",
                "predicted_rating": 0,
                "average_rating": "N/A"
            }])
            
    def get_similar_movies(self, movie_id, top_n=10):
        """Find similar movies based on embeddings"""
        try:
            if movie_id not in self.data_processor.movie_id_lookup:
                raise ValueError("Movie not found")
                
            movie_encoded = self.data_processor.movie_id_lookup[movie_id]
            movie_embedding = self.model.movie_embedding(tf.convert_to_tensor([movie_encoded]))[0]
            
            # Get all movie embeddings
            all_movie_embeddings = self.model.movie_embedding.weights[0].numpy()
            
            # Calculate similarities
            similarities = cosine_similarity([movie_embedding], all_movie_embeddings)[0]
            
            # Get top similar movies (excluding itself)
            similar_indices = np.argsort(-similarities)[1:top_n+1]
            
            similar_movies = pd.DataFrame({
                "movieId": [self.data_processor.reverse_movie_id_lookup[idx] for idx in similar_indices],
                "title": [self.data_processor.movie_titles[self.data_processor.reverse_movie_id_lookup[idx]] 
                          for idx in similar_indices],
                "similarity_score": similarities[similar_indices]
            })
            
            return similar_movies
            
        except Exception as e:
            print(f"Error finding similar movies: {str(e)}")
            return pd.DataFrame()
            
    def full_evaluation(self, k=10, n_users=100):
        """Comprehensive evaluation of the recommender system"""
        results = {}
        
        # Rating prediction metrics
        rating_metrics = self.evaluate_model()
        results.update({
            'TestSet': {
                'RMSE': rating_metrics['rmse'],
                'MAE': rating_metrics['mae'],
            }
        })
        
        # Recommendation quality metrics
        test_users = np.random.choice(
            self.original_test_df['userId'].unique(),
            size=min(n_users, len(self.original_test_df['userId'].unique())),
            replace=False
        )
        
        precisions = []
        recalls = []
        
        for user_id in test_users:
            # Get user's actual positive ratings
            user_ratings = self.original_test_df[self.original_test_df['userId'] == user_id]
            actual_positives = set(user_ratings[user_ratings['user_rating'] >= 4.0]['movieId'])
            
            if not actual_positives:
                continue
                
            # Generate recommendations
            recommendations = self.recommend_for_user(user_id, top_n=k)
            if recommendations.empty:
                continue
                
            recommended_items = set(recommendations['movieId'])
            
            # Calculate metrics
            true_positives = len(actual_positives & recommended_items)
            precisions.append(true_positives / k)
            recalls.append(true_positives / len(actual_positives))
            
        results['Precision@K'] = np.mean(precisions) if precisions else 0
        results['Recall@K'] = np.mean(recalls) if recalls else 0
        
        # Coverage metrics
        test_users = np.random.choice(
            self.original_test_df['userId'].unique(),
            size=min(n_users, len(self.original_test_df['userId'].unique())),
            replace=False
        )
        
        all_recommended = set()
        popularity_counts = defaultdict(int)
        total_movies = len(self.data_processor.movie_ids)
        
        for user_id in test_users:
            recommendations = self.recommend_for_user(user_id, top_n=k)
            if recommendations.empty:
                continue
                
            for movie_id in recommendations['movieId']:
                all_recommended.add(movie_id)
                popularity_counts[movie_id] += 1
                
        results['CatalogCoverage'] = len(all_recommended) / total_movies if total_movies > 0 else 0
        results['AveragePopularity'] = np.mean(list(popularity_counts.values())) if popularity_counts else 0
        
        return results
        
    def save_for_deployment(self, base_path="ncf_deployment"):
        """Save model and necessary components for deployment"""
        os.makedirs(base_path, exist_ok=True)
        
        # Save model
        self.model.save_weights(os.path.join(base_path, "model_weights.weights.h5"))
        
        # Save scaler and data processor info
        with open(os.path.join(base_path, "deployment_assets.pkl"), 'wb') as f:
            pickle.dump({
                'scaler': self.scaler,
                'user_id_lookup': self.data_processor.user_id_lookup,
                'movie_id_lookup': self.data_processor.movie_id_lookup,
                'reverse_movie_id_lookup': self.data_processor.reverse_movie_id_lookup,
                'movie_titles': self.data_processor.movie_titles,
                'user_ids': self.data_processor.user_ids,
                'movie_ids': self.data_processor.movie_ids
            }, f)
            
        print(f"Model and assets saved to {base_path}")
        
    @classmethod
    def load_for_deployment(cls, data_processor, base_path="ncf_deployment"):
        """Load a saved model for deployment"""
        recommender = cls(data_processor)
        
        # Load model weights
        user_count = len(data_processor.user_ids)
        movie_count = len(data_processor.movie_ids)
        
        recommender.model = NeuralCollaborativeFilteringModel(user_count, movie_count)
        recommender.model.load_weights(os.path.join(base_path, "model_weights.weights.h5"))
        
        # Load other assets
        with open(os.path.join(base_path, "deployment_assets.pkl"), 'rb') as f:
            assets = pickle.load(f)
            recommender.scaler = assets['scaler']
            data_processor.user_id_lookup = assets['user_id_lookup']
            data_processor.movie_id_lookup = assets['movie_id_lookup']
            data_processor.reverse_movie_id_lookup = assets['reverse_movie_id_lookup']
            data_processor.movie_titles = assets['movie_titles']
            data_processor.user_ids = assets['user_ids']
            data_processor.movie_ids = assets['movie_ids']
            
        return recommender

# %%
class ModelEvaluator:
    def __init__(self, model, test_ds, scaler,ncf_system,history):
        self.model = model
        self.test_ds = test_ds
        self.scaler = scaler
        self.y_true, self.y_pred = self._get_predictions()
        self.ncf_system = ncf_system
        self.model.history = history
        
    def _get_predictions(self):
        """Get true and predicted values"""
        y_true = []
        y_pred = []
        
        for batch in self.test_ds:
            y_true.extend(batch["user_rating"].numpy())
            y_pred.extend(self.model(batch).numpy().flatten())
            
        y_true = self.scaler.inverse_transform(np.array(y_true).reshape(-1, 1)).flatten()
        y_pred = self.scaler.inverse_transform(np.array(y_pred).reshape(-1, 1)).flatten()
        
        return y_true, y_pred
    
    def plot_rating_distribution(self):
        """Visualize distribution of actual vs predicted ratings"""
        plt.figure(figsize=(10, 6))
        
        sns.kdeplot(self.y_true, label='Actual Ratings', fill=True)
        sns.kdeplot(self.y_pred, label='Predicted Ratings', fill=True)
        
        plt.title('Distribution of Actual vs Predicted Ratings')
        plt.xlabel('Rating')
        plt.ylabel('Density')
        plt.legend()
        plt.show()
        
    def plot_error_distribution(self):
        """Visualize distribution of prediction errors"""
        errors = self.y_pred - self.y_true
        
        plt.figure(figsize=(10, 6))
        sns.histplot(errors, bins=30, kde=True)
        plt.title('Distribution of Prediction Errors')
        plt.xlabel('Prediction Error (Predicted - Actual)')
        plt.ylabel('Count')
        plt.show()
        
    def plot_actual_vs_predicted(self, sample_size=1000):
        """Scatter plot of actual vs predicted ratings"""
        if len(self.y_true) > sample_size:
            indices = np.random.choice(len(self.y_true), sample_size, replace=False)
            y_true_sample = self.y_true[indices]
            y_pred_sample = self.y_pred[indices]
        else:
            y_true_sample = self.y_true
            y_pred_sample = self.y_pred
            
        plt.figure(figsize=(10, 6))
        plt.scatter(y_true_sample, y_pred_sample, alpha=0.5)
        plt.plot([0.5, 5], [0.5, 5], 'r--')  # Perfect prediction line
        plt.title('Actual vs Predicted Ratings')
        plt.xlabel('Actual Ratings')
        plt.ylabel('Predicted Ratings')
        plt.grid(True)
        plt.show()   
        
    def plot_per_rating_metrics(self):
        """Show metrics broken down by actual rating value"""
        rating_values = np.unique(self.y_true.round())
        metrics = []
        plt.figure(figsize=(10, 6))

        for rating in rating_values:
            mask = (self.y_true.round() == rating)
            if sum(mask) == 0:
                continue
                
            rmse = np.sqrt(mean_squared_error(self.y_true[mask], self.y_pred[mask]))
            mae = mean_absolute_error(self.y_true[mask], self.y_pred[mask])
            
            metrics.append({
                'Rating': rating,
                'RMSE': rmse,
                'MAE': mae,
                'Count': sum(mask)
            })
            
        metrics_df = pd.DataFrame(metrics)
        
        fig, ax = plt.subplots(1, 2, figsize=(15, 5))
        
        sns.barplot(data=metrics_df, x='Rating', y='RMSE', ax=ax[0])
        ax[0].set_title('RMSE by Actual Rating')
        
        sns.barplot(data=metrics_df, x='Rating', y='MAE', ax=ax[1])
        ax[1].set_title('MAE by Actual Rating')
        
        plt.tight_layout()
        plt.show()
        
        return metrics_df
    
    def plot_training_history(self, history):
        """Plot training and validation metrics over epochs"""
        plt.figure(figsize=(12, 5))
        
        # Plot RMSE
        plt.subplot(1, 2, 1)
        plt.plot(history.history['root_mean_squared_error'], label='Train RMSE')
        plt.plot(history.history['val_root_mean_squared_error'], label='Validation RMSE')
        plt.title('RMSE Over Epochs')
        plt.xlabel('Epoch')
        plt.ylabel('RMSE')
        plt.legend()
        
        # Plot Loss
        plt.subplot(1, 2, 2)
        plt.plot(history.history['loss'], label='Train Loss')
        plt.plot(history.history['val_loss'], label='Validation Loss')
        plt.title('Loss Over Epochs')
        plt.xlabel('Epoch')
        plt.ylabel('Loss')
        plt.legend()
        
        plt.tight_layout()
        plt.show()

    def perforperformance(self):
        plt.figure(figsize=(10, 6))
        plt.plot(history.history['root_mean_squared_error'], label='Train RMSE', color='blue')
        plt.plot(history.history['val_root_mean_squared_error'], label='Val RMSE', color='orange')
        plt.title("Root Mean Squared Error over Epochs")
        plt.xlabel("Epochs")
        plt.ylabel("RMSE")
        plt.legend()
        plt.grid(True)
        plt.show()
      
        
        
    def generate_full_report(self, history):
        """Generate comprehensive evaluation report"""
        print("="*50)
        print("MODEL EVALUATION REPORT")
        print("="*50)
        
        # Basic metrics
        rmse = np.sqrt(mean_squared_error(self.y_true, self.y_pred))
        mae = mean_absolute_error(self.y_true, self.y_pred)
        
        print(f"\nOverall Metrics:")
        print(f"- RMSE: {rmse:.4f}")
        print(f"- MAE: {mae:.4f}")
        
        # Rating distribution
        print("\nVisualizing Rating Distributions...")
        self.plot_rating_distribution()
        
        # Error analysis
        print("\nVisualizing Prediction Errors...")
        self.plot_error_distribution()
        
        # Actual vs Predicted
        print("\nVisualizing Actual vs Predicted Ratings...")
        self.plot_actual_vs_predicted()

        # Actual vs Predicted
        print("\nperformace of model...")
        self.perforperformance
        
        # Per-rating metrics
        print("\nAnalyzing Performance by Rating Value...")
        metrics_df = self.plot_per_rating_metrics()
        print("\nMetrics by Rating Value:")
        print(metrics_df.to_markdown())
        
        # Training history
        if history:
            print("\nTraining History Visualization...")
            self.plot_training_history(history)
        
        
        print("\nEvaluation complete!")

# %%
df = pd.read_csv("df1.csv")

# %%
df.shape
# Out:
# (999998, 38)

# %%
# select subset of data with user_rating_count > 5
df2 = df[df['user_rating_count'] > 20]

# %%
df2.shape
# Out:
# (278777, 38)

# %%
df.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'userId', 'movieId', 'user_rating',
#        'movie_title', 'user_rating_count', 'user_rating_avg', 'genres',
#        '(no genres listed)', 'Action', 'Adventure', 'Animation', 'Children',
#        'Comedy', 'Crime', 'Documentary', 'Drama', 'Fantasy', 'Film-Noir',
#        'Horror', 'IMAX', 'Musical', 'Mystery', 'Romance', 'Sci-Fi', 'Thriller',
#        'War', 'Western', 'imdbId', 'tmdbId', 'movies_avg_rating', 'year',
#        'month', 'day', 'hour', 'minute', 'movie_year'],
#       dtype='object')

# %%
# Initialize the data processor for Neural Collaborative Filtering
data_processor = NeuralCollaborativeFilteringDataProcessor(df2)

# %%
# Create an instance of the Neural Collaborative Filtering system using the preprocessed data
ncf_system = NeuralCollaborativeFilteringSystem(data_processor)

# %%
# Prepare the training and testing datasets with batching (batch size = 1024)
train_ds, test_ds = ncf_system.prepare_datasets(batch_size=1024)

# %%
# Train the Neural Collaborative Filtering model with specified hyperparameters
# embedding_dim: size of embedding vectors, epochs: number of training cycles, learning_rate: optimizer's step size
history = ncf_system.train_model(
    embedding_dim=64, 
    epochs=20, 
    learning_rate=0.0001
)
# Out:
# Starting training with 223021 samples
# Epoch 1/20
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 17s 58ms/step - loss: 0.1184 - mean_absolute_error: 0.4019 - regularization_loss: 0.0017 - root_mean_squared_error: 0.4637 - total_loss: 0.1200 - val_loss: 0.0383 - val_mean_absolute_error: 0.1628 - val_regularization_loss: 0.0016 - val_root_mean_squared_error: 0.2114 - val_total_loss: 0.0399 - learning_rate: 1.0000e-04
# Epoch 2/20
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 12s 55ms/step - loss: 0.0403 - mean_absolute_error: 0.1588 - regularization_loss: 0.0016 - root_mean_squared_error: 0.2061 - total_loss: 0.0418 - val_loss: 0.0335 - val_mean_absolute_error: 0.1514 - val_regularization_loss: 0.0015 - val_root_mean_squared_error: 0.1953 - val_total_loss: 0.0351 - learning_rate: 1.0000e-04
# Epoch 3/20
# ...

# %%
evaluator = ModelEvaluator(ncf_system.model, ncf_system.test_ds, ncf_system.scaler,ncf_system,history.history)

# %%
evaluator.generate_full_report(history)
# Out:
# ...
# MODEL EVALUATION REPORT
# ...
#
# Overall Metrics:
# - RMSE: 0.9196
# - MAE: 0.7084
#
# Visualizing Rating Distributions...
# Visualizing Prediction Errors...
# Visualizing Actual vs Predicted Ratings...
# performace of model...
#
# Analyzing Performance by Rating Value...
# Metrics by Rating Value:
# |    |   Rating |     RMSE |      MAE |   Count |
# |---:|---------:|---------:|---------:|--------:|
# |  0 |        0 | 2.21623  | 2.05619  |    1217 |
# |  1 |        1 | 1.53184  | 1.37109  |    3431 |
# |  2 |        2 | 0.893086 | 0.737597 |    8973 |
# |  3 |        3 | 0.576162 | 0.4592   |   21012 |
# |  4 |        4 | 0.797521 | 0.634892 |   16808 |
# |  5 |        5 | 1.38708  | 1.24095  |    4315 |
#
# Training History Visualization...
# Evaluation complete!

# %%
ncf_system.full_evaluation()
# Out:
#  1/55 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0341 - mean_absolute_error: 0.1416 - regularization_loss: 0.0027 - root_mean_squared_error: 0.1846 - total_loss: 0.0367
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0338 - mean_absolute_error: 0.1418 - regularization_loss: 0.0027 - root_mean_squared_error: 0.1842 - total_loss: 0.0365
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step
# {'TestSet': {'RMSE': 0.9206271707260717, 'MAE': 0.7092719973325601},
#  'Precision@K': 0.8,
#  'Recall@K': 0.7,
#  'CatalogCoverage': 0.003647951696087886,
#  'AveragePopularity': 11.149425287356323}

# %%
# Save the trained Neural Collaborative Filtering model and related assets for deployment (e.g., to serve or reuse later)
ncf_system.save_for_deployment()
# Out:
# Model and assets saved to ncf_deployment

# %% [markdown]
# ## 6. Deployment Architecture

# %%
# Load the trained Neural Content Based Filtering model and related components from the "my_recommender_deployment" directory
# This allows reuse of the model without retraining
loaded_recommender = NeuralCollaborativeFilteringSystem.load_for_deployment(
    data_processor, "ncf_deployment"
)

# %%
loaded_recommender.recommend_for_user(139143)
# Out:
#    movieId                                       title  \
# 0    60538                                     Shrooms
# 1   141363                                        Chop
# 2   274897                            The Cherokee Kid
# 3   185183  Call Me: The Rise and Fall of Heidi Fleiss
# 4    77835                          Stage Door Canteen
# 5    27837                       Flight of the Phoenix
# 6    47124                              Ant Bully, The
# 7   170825                                    Superbia
# 8   195127                       Jack Irish: Bad Debts
# 9   260627                           Britney Vs Spears
#
#                                              genres  predicted_rating  \
# 0                                   Horror|Thriller          0.059628
# 1                            Comedy|Horror|Thriller          0.056896
# 2                    Action|Children|Comedy|Western          0.056292
# 3                                             Drama          0.055922
# ...

# %%
import gradio as gr
import requests
from urllib.parse import quote

# TMDB API Configuration (same as before)
TMDB_API_KEY = "c4b76d5deff8af9434b07dde68c7c158"
TMDB_BASE_URL = "https://api.themoviedb.org/3"
POSTER_BASE_URL = "https://image.tmdb.org/t/p/w200"


def get_movie_poster(movie_title, year=None):
    """Fetch movie poster URL from TMDB API"""
    try:
        encoded_title = quote(movie_title)
        search_url = (
            f"{TMDB_BASE_URL}/search/movie?api_key={TMDB_API_KEY}&query={encoded_title}"
        )
        if year:
            search_url += f"&year={year}"

        response = requests.get(search_url)
        response.raise_for_status()
        data = response.json()

        if data.get("results"):
            for movie in data["results"]:
                if movie.get("poster_path"):
                    return f"{POSTER_BASE_URL}{movie['poster_path']}"
    except Exception as e:
        print(f"Error fetching poster for {movie_title}: {str(e)}")
    return None


def movie_card(movie_title, genres, rating, year=None):
    """Create a styled movie card with poster"""
    poster_url = get_movie_poster(movie_title, year)

    card = f"""
    <div style="
        display: flex; 
        background: #2d2d2d;
        border-radius: 10px;
        overflow: hidden;
        margin: 10px 0;
        box-shadow: 0 4px 8px rgba(0,0,0,0.2);
        height: 150px;
        width: 100%;
    ">
    """

    if poster_url:
        card += f"""
        <img src="{poster_url}" style="
            height: 150px; 
            width: 100px; 
            object-fit: cover;
        ">
        """
    else:
        card += """
        <div style="
            height: 150px; 
            width: 100px; 
            background: #1f1f1f; 
            display: flex; 
            align-items: center; 
            justify-content: center;
        ">
            <span style="color: #555; font-size: 12px;">No poster</span>
        </div>
        """

    card += f"""
        <div style="padding: 15px; flex-grow: 1;">
            <h3 style="margin: 0; color: #fff; font-weight: 600;">{movie_title}</h3>
            <p style="margin: 5px 0; color: #aaa; font-size: 14px;">{genres}</p>
            <div style="display: flex; align-items: center; margin-top: 10px;">
                <span style="color: #ffb700; font-weight: bold;">⭐ {rating:.1f}</span>
    """

    if year:
        card += f"""
                <span style="margin-left: 15px; color: #888; font-size: 13px;">{year}</span>
        """

    card += """
            </div>
        </div>
    </div>
    """

    return card


def create_recommender_interface(loaded_recommender):
    """Create Gradio interface for the NCF recommender"""
    try:
        # Get movie titles from the recommender's data
        movie_options = (
            loaded_recommender.movie_features["movie_title"].dropna().unique().tolist()
        )
        if not movie_options:
            movie_options = ["No movies available"]
    except Exception as e:
        print(f"Error loading movie options: {str(e)}")
        movie_options = ["Error loading movies"]

    with gr.Blocks(
        theme=gr.themes.Default(
            primary_hue="orange",
            secondary_hue="amber",
            neutral_hue="slate",
            font=[gr.themes.GoogleFont("Poppins")],
        ),
        title="NCF Movie Recommender",
    ) as interface:

        gr.Markdown(
            """
        <div style="text-align: center;">
            <h1 style="color: #ffb700;">🎬 Neural Collaborative Filtering</h1>
            <p style="color: #aaa;">Movie recommendations powered by deep learning</p>
        </div>
        """
        )

        with gr.Tabs():
            with gr.TabItem("User Recommendations"):
                with gr.Row():
                    with gr.Column():
                        user_id = gr.Number(
                            label="User ID",
                            value=139143,  # Your example user ID
                            precision=0,
                        )
                        num_recs = gr.Slider(
                            label="Number of Recommendations",
                            minimum=1,
                            maximum=20,
                            step=1,
                            value=5,
                        )
                        recommend_btn = gr.Button(
                            "Get Recommendations", variant="primary"
                        )
                    with gr.Column():
                        user_output = gr.HTML()

                recommend_btn.click(
                    fn=lambda uid, num: generate_user_recommendations(
                        loaded_recommender, uid, num
                    ),
                    inputs=[user_id, num_recs],
                    outputs=user_output,
                )


    return interface


def generate_user_recommendations(loaded_recommender, user_id, num_recs):
    """Generate recommendations for a user using your NCF system"""
    try:
        user_id = int(user_id)
        if user_id < 1:
            return "❌ Please enter a valid User ID (positive integer)"

        # Use your loaded recommender
        recs = loaded_recommender.recommend_for_user(user_id=user_id, top_n=num_recs)

        if recs is None or recs.empty:
            return "❌ No recommendations found for this user"

        result = (
            "<h2 style='color: #ffb700; margin-bottom: 20px;'>Recommended Movies:</h2>"
        )
        for _, row in recs.iterrows():
            result += movie_card(
                row["title"],
                row.get("genres", ""),
                float(row.get("average_rating", 0)),
                row.get("year", None),
            )
        return result

    except Exception as e:
        return f"❌ Error: {str(e)}"

# %%
# from pyngrok import ngrok

# if __name__ == "__main__":
#     interface = create_recommender_interface(loaded_recommender)
#     public_url = ngrok.connect(7860)  # Forward port 7860
#     print("Public URL (Share this):", public_url)
#     interface.launch()

# %%
# Usage example
if __name__ == "__main__":
    # Load your recommender system (as in your example)
    loaded_recommender = NeuralCollaborativeFilteringSystem.load_for_deployment(
        data_processor, "ncf_deployment"
    )

    # Create and launch interface
    interface = create_recommender_interface(loaded_recommender)
    interface.launch()
# Out:
# Error loading movie options: 'NeuralCollaborativeFilteringSystem' object has no attribute 'movie_features'
# * Running on local URL:  http://127.0.0.1:7870
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7870/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
data_processor.df.sample(5)
# Out:
#         Unnamed: 0.1  Unnamed: 0  userId  movieId  user_rating  \
# 575853        575855      575855  262449     4992            4
# 440              440         440  130759   104881            2
# 673902        673904      673904   13428     3259            3
# 78643          78643       78643  218233     1617            4
# 561958        561960      561960  214027    95510            2
#
#                                               movie_title  user_rating_count  \
# 575853                                     Kate & Leopold                 33
# 440     Out of the Furnace (Dust to Dust) (Low Dweller...                 66
# 673902                                       Far and Away                 35
# 78643                                   L.A. Confidential                 27
# 561958                            Amazing Spider-Man, The                 24
#
#         user_rating_avg                            genres  (no genres listed)  \
# ...
